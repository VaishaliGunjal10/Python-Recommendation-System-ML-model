# %%
import pandas as pd
import numpy as np

# %%
fn=pd.read_csv("book (1).csv")
fn
# Out:
#          no  UserID                                          BookTitle  \
# 0         1  276726                                Classical Mythology
# 1         2  276729                                       Clara Callan
# 2         3  276729                               Decision in Normandy
# 3         4  276736  Flu: The Story of the Great Influenza Pandemic...
# 4         5  276737                             The Mummies of Urumchi
# ...     ...     ...                                                ...
# 9995   9996  162121       American Fried: Adventures of a Happy Eater.
# 9996   9997  162121                              Cannibal In Manhattan
# 9997   9998  162121                    How to Flirt: A Practical Guide
# 9998   9999  162121                                           Twilight
# 9999  10000  162129                       Kids Say the Darndest Things
#
#       BookRating
# 0              5
# 1              3
# 2              6
# 3              8
# 4              6
# ...

# %%
len(fn.UserID.unique())
# Out:
# 2182

# %%
len(fn.BookTitle.unique())
# Out:
# 9659

# %%
fn.groupby('BookTitle')['BookRating'].mean().sort_values(ascending=False).head()
# Out:
# BookTitle
# Clear Light of Day                                         10.0
# Substitute Teaching: A Handbook for Hassle-Free Subbing    10.0
# Daughter of Camelot (Merlin's Legacy, No 6)                10.0
# The Resourceful English Teacher                            10.0
# Das verbotene Lied.                                        10.0
# Name: BookRating, dtype: float64

# %%
fn.groupby('BookTitle')['BookRating'].count().sort_values(ascending=False).head()
# Out:
# BookTitle
# Fahrenheit 451                                     5
# Vanished                                           4
# Charlie and the Chocolate Factory                  4
# Stardust                                           4
# The Amber Spyglass (His Dark Materials, Book 3)    4
# Name: BookRating, dtype: int64

# %%
ratings = pd.DataFrame(fn.groupby('BookTitle')['BookRating'].mean())
ratings.head()
# Out:
#                                                     BookRating
# BookTitle
#  Jason, Madison &amp                                       8.0
#  Other Stories;Merril;1985;McClelland &amp                 6.0
#  Repairing PC Drives &amp                                  4.0
# '48                                                        7.0
# 'O Au No Keia: Voices from Hawai'I's Mahu and T...         8.0

# %%
ratings['num of ratings'] = pd.DataFrame(fn.groupby('BookTitle')['BookRating'].count())
ratings.head()
# Out:
#                                                     BookRating  num of ratings
# BookTitle
#  Jason, Madison &amp                                       8.0               1
#  Other Stories;Merril;1985;McClelland &amp                 6.0               1
#  Repairing PC Drives &amp                                  4.0               1
# '48                                                        7.0               1
# 'O Au No Keia: Voices from Hawai'I's Mahu and T...         8.0               1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)

# %%
plt.figure(figsize=(10,4))
ratings['BookRating'].hist(bins=70)

# %%
sns.jointplot(x='BookRating',y='num of ratings',data=ratings,alpha=0.5)

# %%
fn_user = fn.pivot_table(index='UserID',
                                 columns='BookTitle',
                                 values='BookRating' ) 
fn_user
# Out:
# BookTitle   Jason, Madison &amp   Other Stories;Merril;1985;McClelland &amp  \
# UserID
# 8                           NaN                                         NaN
# 9                           NaN                                         NaN
# 10                          NaN                                         NaN
# 12                          NaN                                         NaN
# 14                          NaN                                         NaN
# ...                         ...                                         ...
# 278846                      NaN                                         NaN
# 278849                      NaN                                         NaN
# 278851                      NaN                                         NaN
# 278852                      NaN                                         NaN
# 278854                      NaN                                         NaN
#
# BookTitle   Repairing PC Drives &amp  '48  \
# ...

# %%
fn_user.index = fn.UserID.unique()

# %%
fn_user
# Out:
# BookTitle   Jason, Madison &amp   Other Stories;Merril;1985;McClelland &amp  \
# UserID
# 8                           NaN                                         NaN
# 9                           NaN                                         NaN
# 10                          NaN                                         NaN
# 12                          NaN                                         NaN
# 14                          NaN                                         NaN
# ...                         ...                                         ...
# 278846                      NaN                                         NaN
# 278849                      NaN                                         NaN
# 278851                      NaN                                         NaN
# 278852                      NaN                                         NaN
# 278854                      NaN                                         NaN
#
# BookTitle   Repairing PC Drives &amp  '48  \
# ...

# %%
fn_user.fillna(0, inplace=True)
fn_user
# Out:
# BookTitle   Jason, Madison &amp   Other Stories;Merril;1985;McClelland &amp  \
# UserID
# 8                           0.0                                         0.0
# 9                           0.0                                         0.0
# 10                          0.0                                         0.0
# 12                          0.0                                         0.0
# 14                          0.0                                         0.0
# ...                         ...                                         ...
# 278846                      0.0                                         0.0
# 278849                      0.0                                         0.0
# 278851                      0.0                                         0.0
# 278852                      0.0                                         0.0
# 278854                      0.0                                         0.0
#
# BookTitle   Repairing PC Drives &amp  '48  \
# ...

# %%
ratings
# Out:
#                                                     BookRating  num of ratings
# BookTitle
#  Jason, Madison &amp                                       8.0               1
#  Other Stories;Merril;1985;McClelland &amp                 6.0               1
#  Repairing PC Drives &amp                                  4.0               1
# '48                                                        7.0               1
# 'O Au No Keia: Voices from Hawai'I's Mahu and T...         8.0               1
# ...                                                        ...             ...
# \Surely You're Joking, Mr. Feynman!\: Adventure...         8.0               1
# \Well, there's your problem\: Cartoons                     9.0               1
# iI Paradiso Degli Orchi                                    7.0               1
# stardust                                                   5.0               1
# Ã?Â?bermorgen.                                             4.0               1
#
# ...

# %%
ratings.sort_values('num of ratings',ascending=False)
# Out:
#                                                     BookRating  num of ratings
# BookTitle
# Fahrenheit 451                                            7.00               5
# Ender's Game (Ender Wiggins Saga (Paperback))             6.25               4
# Stardust                                                  8.50               4
# Vanished                                                  6.50               4
# Charlie and the Chocolate Factory                         6.50               4
# ...                                                        ...             ...
# His and Hers: Ranchin' Dads (Harlequin - Wester...        9.00               1
# His-And-Hers Twins (Harlequin American Romance,...       10.00               1
# Histoires Extraordinaires                                 7.00               1
# Historia de la vida del BuscÃ³n (Selecciones Au...       10.00               1
# Ã?Â?bermorgen.                                            4.00               1
#
# ...

# %%
FahrenheitBook=fn_user["Fahrenheit 451"]
StardustBook=fn_user["Stardust"]
FahrenheitBook
# Out:
# UserID
# 8         0.0
# 9         0.0
# 10        0.0
# 12        0.0
# 14        0.0
#          ...
# 278846    0.0
# 278849    0.0
# 278851    0.0
# 278852    0.0
# 278854    0.0
# Name: Fahrenheit 451, Length: 2182, dtype: float64

# %%
similar_to_FahrenheitBook = fn_user.corrwith(FahrenheitBook)
similar_to_StardustBook = fn_user.corrwith(StardustBook)

# %%
corr_FahrenheitBook = pd.DataFrame(similar_to_FahrenheitBook,columns=['Correlation'])
corr_FahrenheitBook.dropna(inplace=True)
corr_FahrenheitBook
# Out:
#                                                     Correlation
# BookTitle
#  Jason, Madison &amp                                  -0.000958
#  Other Stories;Merril;1985;McClelland &amp            -0.000958
#  Repairing PC Drives &amp                             -0.000958
# '48                                                   -0.000958
# 'O Au No Keia: Voices from Hawai'I's Mahu and T...    -0.000958
# ...                                                         ...
# \Surely You're Joking, Mr. Feynman!\: Adventure...    -0.000958
# \Well, there's your problem\: Cartoons                -0.000958
# iI Paradiso Degli Orchi                               -0.000958
# stardust                                              -0.000958
# Ã?Â?bermorgen.                                        -0.000958
#
# [9659 rows x 1 columns]

# %%
corr_FahrenheitBook.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation
# BookTitle
# Fahrenheit 451                                         1.000000
# The Day I Swapped My Dad for 2 Goldfish                0.596326
# The Onion Girl                                         0.596326
# Bloodcurdling Tales of Horror                          0.596326
# The Ambassador's Women                                 0.596326
# Silent Witness                                         0.596326
# Dream Country (Sandman, Book 3)                        0.596326
# Mr. Punch                                              0.596326
# Tap d'escopeta (MÃ­nima de butxaca)                    0.596326
# Les illes grogues: Tres novelÂ¨les romÃ ntiques...     0.596326

# %%
corr_FahrenheitBook = corr_FahrenheitBook.join(ratings['num of ratings'])
corr_FahrenheitBook.head()
# Out:
#                                                     Correlation  \
# BookTitle
#  Jason, Madison &amp                                  -0.000958
#  Other Stories;Merril;1985;McClelland &amp            -0.000958
#  Repairing PC Drives &amp                             -0.000958
# '48                                                   -0.000958
# 'O Au No Keia: Voices from Hawai'I's Mahu and T...    -0.000958
#
#                                                     num of ratings
# BookTitle
#  Jason, Madison &amp                                             1
#  Other Stories;Merril;1985;McClelland &amp                       1
#  Repairing PC Drives &amp                                        1
# '48                                                              1
# 'O Au No Keia: Voices from Hawai'I's Mahu and T...               1

# %%
corr_FahrenheitBook[corr_FahrenheitBook['num of ratings']>3].sort_values('Correlation',ascending=False).head()
# Out:
#                                                  Correlation  num of ratings
# BookTitle
# Fahrenheit 451                                      1.000000               5
# Vanished                                            0.224660               4
# Ender's Game (Ender Wiggins Saga (Paperback))       0.161969               4
# The Amber Spyglass (His Dark Materials, Book 3)    -0.001836               4
# Charlie and the Chocolate Factory                  -0.001890               4

# %%
corr_StardustBook = pd.DataFrame(similar_to_StardustBook,columns=['Correlation'])
corr_StardustBook.dropna(inplace=True)
corr_StardustBook = corr_StardustBook.join(ratings['num of ratings'])
corr_StardustBook[corr_StardustBook['num of ratings']>3].sort_values('Correlation',ascending=False).head()
# Out:
#                                                  Correlation  num of ratings
# BookTitle
# Stardust                                            1.000000               4
# The Amber Spyglass (His Dark Materials, Book 3)    -0.001749               4
# Ender's Game (Ender Wiggins Saga (Paperback))      -0.001789               4
# Vanished                                           -0.001801               4
# Charlie and the Chocolate Factory                  -0.001801               4
